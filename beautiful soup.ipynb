# %%
# !pip3 install request
import requests
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
url = 'https://www.python.org/jobs/'
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '\n\n<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta nam
# ...

# %%
req.text[:200]
# Out:
# '\n\n<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      '

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(req.text, 'lxml')

# %%
jobs = soup.find('ol', {'class':'list-recent-jobs'})

# %%
jobs
# Out:
# <ol class="list-recent-jobs list-row-container menu">
# <li>
# <h2 class="listing-company">
# <span class="listing-company-name">
# <span class="listing-new">New</span>
# <a href="/jobs/4448/">Lead Python Engineer (Back End)</a><br/>
# 		    Big Data, BI, Analytics, Workforce Management Software Development Company
#                 </span>
# <span class="listing-location"><a href="/jobs/location/huntington-beach-ca-united-states/" title="More jobs in Huntington Beach, CA, United States">Huntington Beach, CA, United States</a></span>
# </h2>
# <span class="listing-job-type"><a href="/jobs/type/back-end/" title="More Back end jobs">Back end</a>, <a href="/jobs/type/big-data/" title="More Big Data jobs">Big Data</a>, <a href="/jobs/type/cloud/" title="More Cloud jobs">Cloud</a>, <a href="/jobs/type/lead/" title="More Lead jobs">Lead</a>, Python 3.7, FLASK, AWS
#             </span>
# ...

# %%
type(jobs.findAll())
# Out:
# bs4.element.ResultSet

# %%
jobs.findAll('li')
# Out:
# [<li>
#  <h2 class="listing-company">
#  <span class="listing-company-name">
#  <span class="listing-new">New</span>
#  <a href="/jobs/4448/">Lead Python Engineer (Back End)</a><br/>
#  		    Big Data, BI, Analytics, Workforce Management Software Development Company
#                  </span>
#  <span class="listing-location"><a href="/jobs/location/huntington-beach-ca-united-states/" title="More jobs in Huntington Beach, CA, United States">Huntington Beach, CA, United States</a></span>
#  </h2>
#  <span class="listing-job-type"><a href="/jobs/type/back-end/" title="More Back end jobs">Back end</a>, <a href="/jobs/type/big-data/" title="More Big Data jobs">Big Data</a>, <a href="/jobs/type/cloud/" title="More Cloud jobs">Cloud</a>, <a href="/jobs/type/lead/" title="More Lead jobs">Lead</a>, Python 3.7, FLASK, AWS
#              </span>
#  <span class="listing-posted">Posted: <time datetime="2020-03-03T20:04:41.514915+00:00">03 March 2020</time></span>
# ...

# %%
for job in jobs.findAll('li'):
    d = dict()
    d['company name'] = job.find('span' ,{'class':'listing-company-name'}).text
    d['job type'] = job.find('span' , {'class':'listing-job-type'}).text
    d['company location'] = job.find('span', {'class':'listing-location'}).text
    d['time posted'] = job.find('span', {'class':'listing-posted'}).text
    d['company category'] = job.find('span', {'class':'listing-company-category'}).text
    
    print(d)
# Out:
# {'company name': '\nNew\nLead Python Engineer (Back End)\n\t\t    Big Data, BI, Analytics, Workforce Management Software Development Company\n                ', 'job type': 'Back end, Big Data, Cloud, Lead, Python 3.7, FLASK, AWS \n            ', 'company location': 'Huntington Beach, CA, United States', 'time posted': 'Posted: 03 March 2020', 'company category': 'Developer / Engineer'}
# {'company name': '\nNew\nSenior Python Engineer Munich (m/f/x)\n\t\t    Alasco GmbH\n                ', 'job type': 'Back end, Cloud, Database, Finance, Front end, Lead, Management, Operations, Testing, Web\n', 'company location': 'Munich, Bavaria, Germany', 'time posted': 'Posted: 03 March 2020', 'company category': 'Developer / Engineer'}
# ...

# %%
l_head = []
for e in jobs.findAll('h2'):
    l_head.append(e.find('a').text)
l_head
# Out:
# ['Lead Python Engineer (Back End)',
#  'Senior Python Engineer Munich (m/f/x)',
#  'Python Engineer',
#  'Python Developer',
#  'Python-django Developer',
#  'Data Engineers (Mid & Senior)',
#  'Senior Python Engineer',
#  'Lead Python Developer Role - Rapidly Growing Cybersecurity Company - Nashville, TN',
#  'Senior Backend Developer (Python/Django)',
#  'Python Developer',
#  'Senior Python Software Developer',
#  'Python Developer',
#  'Collections and Information Developer',
#  'Python Full Stack Engineer (JavaScript/Node.js/React)',
#  'ERP5 Python Developer for Automotive',
#  'Python PyData and Javascript Project Developer',
#  'Remote Senior Python Developer',
#  'Edge Computing for 4G/5G Telco',
#  'Python Out Of Core Numpy Developer',
#  'Open Source Robot / Industrial Automation',
#  'Artificial Optical Inspection (AOI)',
#  'Jupyter Lab Mass Deployment',
#  'High-performance Python without GIL via type inference and thread-safe memory management in Cython',
# ...

# %%
l_company_loc = []
for e in events.findAll('h2'):
    l_company_loc.append(e.find('span', {'class':'listing-location'}).text)
l_company_loc
# Out:
# ['Huntington Beach, CA, United States',
#  'Munich, Bavaria, Germany',
#  'London, Hammersmith, United Kingdom',
#  'Barcelona, Spain',
#  'Vadodara, Gujarat, India',
#  'London, United Kingdom',
#  'Bogotá- Colombia, Bogota, Colombia',
#  'Nashville, TN, United States',
#  'Vienna, Austria',
#  'Montreal, Quebec, Canada',
#  'Montreal, Quebec, Canada',
#  'Bristol, United Kingdom',
#  'London, London, United Kingdom',
#  'New York, NY, United States',
#  'Lille, France',
#  'Lille, France',
#  'Warsaw, Poland',
#  'Lille, France',
#  'Lille, France',
#  'Lille, France',
#  'Lille, France',
#  'Lille, France',
#  'Lille, France',
#  'Madrid, Spain',
#  'Sydney, NSW, Australia']

# %%
l_job_type = []
for e in events.findAll('span', {'class':'listing-job-type'}):
    l_job_type.append(e.find('a').text)
l_job_type
# Out:
# ['Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Back end',
#  'Cloud',
#  'Back end',
#  'Back end',
#  'Cloud',
#  'Big Data',
#  'Integration',
#  'Big Data',
#  'Back end',
#  'Systems',
#  'Back end',
#  'Back end']

# %%
l_time_posted = []
for e in events.findAll('span', {'class':'listing-posted'}):
    l_time_posted.append(e.find('time').text)
l_time_posted
# Out:
# ['03 March 2020',
#  '03 March 2020',
#  '03 March 2020',
#  '02 March 2020',
#  '28 February 2020',
#  '27 February 2020',
#  '26 February 2020',
#  '25 February 2020',
#  '24 February 2020',
#  '21 February 2020',
#  '20 February 2020',
#  '19 February 2020',
#  '19 February 2020',
#  '12 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '11 February 2020',
#  '10 February 2020',
#  '10 February 2020']

# %%
l_comp_cat = []
for e in events.findAll('span', {'class':'listing-company-category'}):
    l_comp_cat.append(e.find('a').text)
l_comp_cat
# Out:
# ['Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Other',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer',
#  'Developer / Engineer']

# %%
import pandas as pd

df = pd.DataFrame()

df['company name'] = l_head
df['posted time'] = l_time_posted
df['company location'] = l_company_loc
df['company category'] = l_comp_cat
df['job type'] = l_job_type

df
# Out:
#                                          company name       posted time  \
# 0                     Lead Python Engineer (Back End)     03 March 2020
# 1               Senior Python Engineer Munich (m/f/x)     03 March 2020
# 2                                     Python Engineer     03 March 2020
# 3                                    Python Developer     02 March 2020
# 4                             Python-django Developer  28 February 2020
# 5                       Data Engineers (Mid & Senior)  27 February 2020
# 6                              Senior Python Engineer  26 February 2020
# 7   Lead Python Developer Role - Rapidly Growing C...  25 February 2020
# 8            Senior Backend Developer (Python/Django)  24 February 2020
# 9                                    Python Developer  21 February 2020
# 10                   Senior Python Software Developer  20 February 2020
# 11                                   Python Developer  19 February 2020
# ...
